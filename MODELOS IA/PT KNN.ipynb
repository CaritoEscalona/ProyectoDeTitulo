# %%
# DATASET CARDIOVASCULAR
# Importa las bibliotecas necesarias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Carga de dataset y división de conjunto de datos en características (X) y etiquetas (y)
df = pd.read_csv('/content/cardio_train.csv')
selected_features = ["Ejection.Fraction", "Creatinine"]
X = df[selected_features]
y = df['Event']

# Normaliza los datos y divide el conjunto en entrenamiento y prueba.
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Inicializa el clasificador KNN (n_neighbors se puede ajustar)
knn = KNeighborsClassifier(n_neighbors=5)

# Entrena el modelo y realización de predicciones.
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# Evalúa la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo: {accuracy:.2f}')

# Muestra el reporte de clasificación
print('\nReporte de clasificación:\n', classification_report(y_test, y_pred))

# Generar la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Visualización de la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=knn.classes_, yticklabels=knn.classes_)
plt.ylabel('Etiqueta Verdadera')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión')
plt.show()
# Out:
# Precisión del modelo: 0.75
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79        39
#            1       0.61      0.81      0.69        21
#
#     accuracy                           0.75        60
#    macro avg       0.74      0.76      0.74        60
# weighted avg       0.78      0.75      0.76        60

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# y_true serían tus etiquetas verdaderas
# y_scores serían las probabilidades o puntuaciones de decisión de la clase positiva
auc_roc = roc_auc_score(y_test, y_pred)
print(f'AUC-ROC: {auc_roc:.2f}')

# Calcular los valores de tasa verdadera positiva (TPR) y tasa falsa positiva (FPR) para diferentes umbrales
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Generar la gráfica para AUC-ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {auc_roc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC: 0.76

# %%
# DATASET HEART DISEASE
# Importa las bibliotecas necesarias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Carga de conjunto de datos y división en características X y etiqueta Y.
df = pd.read_csv('/content/heart.csv')
X = df.drop('target', axis=1)
y = df['target']

# Normaliza los datos y divide el conjunto en entrenamiento y prueba.
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Inicializa el clasificador KNN (n_neighbors se puede ajustar)
knn = KNeighborsClassifier(n_neighbors=5)

# Entrena el modelo y realización de predicciones.
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# Evalúa la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo: {accuracy:.2f}')

# Muestra el reporte de clasificación
print('\nReporte de clasificación:\n', classification_report(y_test, y_pred))

# Generar la matriz de confusión
cm = confusion_matrix(y_test, y_pred)

# Visualización de la matriz de confusión
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=knn.classes_, yticklabels=knn.classes_)
plt.ylabel('Etiqueta Verdadera')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión')
plt.show()
# Out:
# Precisión del modelo: 0.86
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       102
#            1       0.86      0.86      0.86       103
#
#     accuracy                           0.86       205
#    macro avg       0.86      0.86      0.86       205
# weighted avg       0.86      0.86      0.86       205

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# y_true serían tus etiquetas verdaderas
# y_scores serían las probabilidades o puntuaciones de decisión de la clase positiva
auc_roc = roc_auc_score(y_test, y_pred)
print(f'AUC-ROC: {auc_roc:.2f}')

# Calcular los valores de tasa verdadera positiva (TPR) y tasa falsa positiva (FPR) para diferentes umbrales
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Generar la gráfica para AUC-ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {auc_roc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC: 0.86
